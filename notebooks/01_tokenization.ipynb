# %% [markdown]
# # Prompt Tokenization\n\nThis notebook shows how a banking prompt is split into word-level tokens.

# %%
from src.tokenizer import WordTokenizer\n\ntext = \"You are a banking tutor. Explain how a savings account earns interest over time.\"\ntokenizer = WordTokenizer().fit(text)\nprint(tokenizer.tokenize(text))\nprint(tokenizer.encode(text))
