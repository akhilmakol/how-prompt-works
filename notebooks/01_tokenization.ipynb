# %% [markdown]
# # Tokenization\n\nThis notebook shows how the banking corpus is split into word-level tokens.

# %%
from src.tokenizer import WordTokenizer\n\ntext = \"A savings account earns interest over time.\"\ntokenizer = WordTokenizer().fit(text)\nprint(tokenizer.tokenize(text))\nprint(tokenizer.encode(text))
