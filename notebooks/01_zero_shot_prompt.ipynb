# %% [markdown]
# # Zero-shot Prompt\n\nThis notebook shows how a simple banking prompt works without any examples.

# %%
from src.generate import generate_text\n\nprompt = \"Explain a savings account in simple language.\"\nprint(generate_text(prompt, max_new_tokens=12))
