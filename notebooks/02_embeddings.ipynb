# %% [markdown]
# # Prompt Embeddings\n\nThis notebook inspects token and position embeddings for a banking prompt.

# %%
import torch\nfrom src.embeddings import TokenPositionEmbedding\n\nlayer = TokenPositionEmbedding(vocab_size=20, embed_dim=8, block_size=10)\ninput_ids = torch.tensor([[1, 2, 3, 4]])\nprint(layer(input_ids).shape)
