# %% [markdown]
# # One-shot Prompt\n\nThis notebook demonstrates a single banking example before the real task.

# %%
from src.tokenizer import WordTokenizer\n\nprompt = \"Deposit -> banking term\\nMortgage -> ?\"\ntokenizer = WordTokenizer().fit(prompt)\nprint(tokenizer.tokenize(prompt))\nprint(tokenizer.encode(prompt))
