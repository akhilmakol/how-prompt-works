# %% [markdown]
# # Few-shot Prompt\n\nThis notebook shows how multiple banking examples create a stronger pattern.

# %%
from src.tokenizer import WordTokenizer\n\nprompt = \"Savings account -> deposit product\\nMortgage -> loan product\\nCredit card -> ?\"\ntokenizer = WordTokenizer().fit(prompt)\nprint(tokenizer.tokenize(prompt))\nprint(tokenizer.encode(prompt))
