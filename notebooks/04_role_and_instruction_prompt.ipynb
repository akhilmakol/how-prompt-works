# %% [markdown]
# # Instruction and Role-based Prompt\n\nThis notebook compares direct instructions with role-based banking prompts.

# %%
examples = [\n    \"Write a professional summary of mortgage interest for new customers.\",\n    \"You are a senior loan officer. Explain mortgage interest to a first-time borrower.\",\n]\nfor item in examples:\n    print(item)\n    print()
