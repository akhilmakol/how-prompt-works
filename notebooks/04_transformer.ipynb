# %% [markdown]
# # Transformer Block\n\nThis notebook runs one transformer block on sample hidden states.

# %%
import torch\nfrom src.transformer import TransformerBlock\n\nblock = TransformerBlock(embed_dim=16, num_heads=4)\nx = torch.randn(2, 5, 16)\ny, attn = block(x)\nprint(y.shape)\nprint(attn.shape)
