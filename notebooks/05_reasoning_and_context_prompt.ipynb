# %% [markdown]
# # Chain-of-Thought and Contextual Prompt\n\nThis notebook highlights reasoning prompts and context-rich banking prompts.

# %%
prompts = [\n    \"Explain step by step how interest on a savings account is calculated.\",\n    \"Our fintech app serves first-time borrowers. Suggest features for a loan education assistant.\",\n]\nfor prompt in prompts:\n    print(prompt)\n    print('-' * 40)
