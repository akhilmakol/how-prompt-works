# %% [markdown]
# # Training\n\nThis notebook launches the end-to-end training pipeline for the banking prompt corpus.

# %%
from src.train import train_model\n\nmodel, tokenizer, losses = train_model()\nprint(f\"Trained vocab size: {tokenizer.vocab_size}\")\nprint(f\"Final loss: {losses[-1]:.4f}\")
