# %% [markdown]
# # Conversational, Output-constrained, and Creative Prompt\n\nThis notebook groups prompt types often used in banking assistants, automation, and storytelling.

# %%
examples = {\n    \"Conversational\": \"User: I need a bank account. AI: What matters most: low fees, high interest, or mobile access?\",\n    \"Output-constrained\": \"Return JSON with fields: product_name, benefit, risk.\",\n    \"Creative\": \"Write a short story about an AI banker teaching children why saving money matters.\",\n}\nfor label, prompt in examples.items():\n    print(label)\n    print(prompt)\n    print()
