# %% [markdown]
# # Generation\n\nThis notebook loads the saved model and generates banking-themed text.

# %%
from src.generate import generate_text\n\nprint(generate_text(\"a bank offers\", max_new_tokens=12))
