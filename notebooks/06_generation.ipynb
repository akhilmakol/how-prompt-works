# %% [markdown]
# # Prompted Generation\n\nThis notebook loads the saved model and generates banking-themed text from a prompt.

# %%
from src.generate import generate_text\n\nprint(generate_text(\"You are a banking tutor. Explain what a bank offers\", max_new_tokens=12))
